# %% [markdown]
# # Demo: Explainable Contrastive Anomaly Detection
# This notebook demonstrates pretraining, detector fitting, and explanations.

# %%
from xadl.training.contrastive_trainer import train as pretrain
from xadl.training.detector_trainer import train_detector
cfg='configs/tabular_small.yaml'
pretrain(cfg, 'artifacts/encoder.pt')
train_detector(cfg, 'artifacts/encoder.pt', None)
print('Done')
